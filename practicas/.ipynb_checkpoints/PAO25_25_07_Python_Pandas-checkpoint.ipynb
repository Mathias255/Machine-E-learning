# %% [markdown]
# ![logo](img/logoitqv1.jpg)
# <br>
# # 0.1 PAO 25-25 - Pandas
#
# <br>
#
# ![python](img/python_logo.png)
#
# <br>
#
# *Alexis González*
#
# <br>
#
# [link de Git Hub](https://github.com/Mathias255/Machine-E-learning.git)

# %% [markdown]
# ## 1 Pandas
# * Librería (de facto estándar) para estructurar datos tabulares
# * Multivariable (string, int, float, bool…)
# * Dos clases:
#
#       – Series (1 dimensión)
#       – DataFrames (2+ dimensiones)

# %%
# librería externa
import pandas as pd
from pandas import Series, DataFrame

# %%
pd.__version__
# Out:
# '3.0.3'

# %% [markdown]
# ## 2 Series
# * Datos unidimensionales (similar a NumPy)
# * Elementos + índices modificables

# %%
countries = pd.Series(['Spain','Andorra','Gibraltar','Portugal','France'])
print(countries)
# Out:
# 0        Spain
# 1      Andorra
# 2    Gibraltar
# 3     Portugal
# 4       France
# dtype: str

# %%
# especificando el índice
countries = pd.Series(['Spain','Andorra','Gibraltar','Portugal','France'],
                       index=range(10,60,10))
print(countries)
# Out:
# 10        Spain
# 20      Andorra
# 30    Gibraltar
# 40     Portugal
# 50       France
# dtype: str

# %%
# los índices pueden ser de más tipos
football_cities = pd.Series(['Barcelona','Madrid','Valencia','Sevilla'],
                              index=['a','b','c','d'])
print(football_cities)
# Out:
# a    Barcelona
# b       Madrid
# c     Valencia
# d      Sevilla
# dtype: str

# %%
# Atributos
football_cities.name = 'Ciudades con dos equipos en primera' # nombrar la Serie
football_cities.index.name = 'Id' # Describir los índices
print(football_cities)
# Out:
# Id
# a    Barcelona
# b       Madrid
# c     Valencia
# d      Sevilla
# Name: Ciudades con dos equipos en primera, dtype: str

# %%
# acceso similar a NumPy o listas, según posición (depecrated)
print(football_cities[2])

# acceso a través del índice semántico
print(football_cities['c'])

print(football_cities['c'] == football_cities[2])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\Trabajos_Machine_2026\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
# --> 176 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:583, in pandas._libs.index.StringObjectEngine._check_type()
# --> 583 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 2
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 2
#       1 # acceso similar a NumPy o listas, según posición (depecrated)
# ----> 2 print(football_cities[2])
#       3
#       4 # acceso a través del índice semántico
#       5 print(football_cities['c'])
#
# File ~\anaconda3\envs\Trabajos_Machine_2026\Lib\site-packages\pandas\core\series.py:959, in Series.__getitem__(self, key)
#     954     key = unpack_1tuple(key)
#     956 elif key_is_scalar:
#     957     # Note: GH#50617 in 3.0 we changed int key to always be treated as
#     958     #  a label, matching DataFrame behavior.
# --> 959     return self._get_value(key)
#     961 # Convert generator to list before going through hashable part
#     962 # (We will iterate through the generator there to check for slices)
#     963 if is_iterator(key):
#
# File ~\anaconda3\envs\Trabajos_Machine_2026\Lib\site-packages\pandas\core\series.py:1046, in Series._get_value(self, label, takeable)
#    1043     return self._values[label]
#    1045 # Similar to Index.get_value, but we do not fall back to positional
# -> 1046 loc = self.index.get_loc(label)
#    1048 if is_integer(loc):
#    1049     return self._values[loc]
#
# File ~\anaconda3\envs\Trabajos_Machine_2026\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 2

# %% [markdown]
# ## 3 Tratamiento similar a ndarray

# %%
 # múltiple recolección de elementos
print(football_cities[ ['a','c'] ])
print(football_cities[ [0, 3] ])
# Out:
# Id
# a    Barcelona
# c     Valencia
# Name: Ciudades con dos equipos en primera, dtype: str
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 3
#       1  # múltiple recolección de elementos
#       2 print(football_cities[ ['a','c'] ])
# ----> 3 print(football_cities[ [0, 3] ])
#
# File ~\anaconda3\envs\Trabajos_Machine_2026\Lib\site-packages\pandas\core\series.py:991, in Series.__getitem__(self, key)
#     988     key = np.asarray(key, dtype=bool)
#     989     return self._get_rows_with_mask(key)
# --> 991 return self._get_with(key)
#
# File ~\anaconda3\envs\Trabajos_Machine_2026\Lib\site-packages\pandas\core\series.py:1003, in Series._get_with(self, key)
#    1000 elif isinstance(key, tuple):
#    1001     return self._get_values_tuple(key)
# -> 1003 return self.loc[key]
#
# File ~\anaconda3\envs\Trabajos_Machine_2026\Lib\site-packages\pandas\core\indexing.py:1207, in _LocationIndexer.__getitem__(self, key)
#    1205 maybe_callable = com.apply_if_callable(key, self.obj)
#    1206 maybe_callable = self._raise_callable_usage(key, maybe_callable)
# -> 1207 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\envs\Trabajos_Machine_2026\Lib\site-packages\pandas\core\indexing.py:1438, in _LocIndexer._getitem_axis(self, key, axis)
#    1435     if hasattr(key, "ndim") and key.ndim > 1:
#    1436         raise ValueError("Cannot index with multidimensional key")
# -> 1438     return self._getitem_iterable(key, axis=axis)
#    1440 # nested tuple slicing
#    1441 if is_nested_tuple(key, labels):
#
# File ~\anaconda3\envs\Trabajos_Machine_2026\Lib\site-packages\pandas\core\indexing.py:1378, in _LocIndexer._getitem_iterable(self, key, axis)
#    1375 self._validate_key(key, axis)
#    1377 # A collection of keys
# -> 1378 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1379 return self.obj._reindex_with_indexers(
#    1380     {axis: [keyarr, indexer]}, allow_dups=True
#    1381 )
#
# File ~\anaconda3\envs\Trabajos_Machine_2026\Lib\site-packages\pandas\core\indexing.py:1576, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1573 ax = self.obj._get_axis(axis)
#    1574 axis_name = self.obj._get_axis_name(axis)
# -> 1576 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1578 return keyarr, indexer
#
# File ~\anaconda3\envs\Trabajos_Machine_2026\Lib\site-packages\pandas\core\indexes\base.py:6302, in Index._get_indexer_strict(self, key, axis_name)
#    6299 else:
#    6300     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6302 self._raise_if_missing(keyarr, indexer, axis_name)
#    6304 keyarr = self.take(indexer)
#    6305 if isinstance(key, Index):
#    6306     # GH 42790 - Preserve name from an Index
#
# File ~\anaconda3\envs\Trabajos_Machine_2026\Lib\site-packages\pandas\core\indexes\base.py:6352, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6350 if nmissing:
#    6351     if nmissing == len(indexer):
# -> 6352         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6354     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6355     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index([0, 3], dtype='int64', name='Id')] are in the [index]"

# %%
# slicing
print(football_cities[:'c']) # incluye ambos extremos con el indice semantico
print(football_cities[:2])
# Out:
# Id
# a    Barcelona
# b       Madrid
# c     Valencia
# Name: Ciudades con dos equipos en primera, dtype: str
# Id
# a    Barcelona
# b       Madrid
# Name: Ciudades con dos equipos en primera, dtype: str

# %%
#cast a list
lista = list(football_cities[:'c'])
print(lista)
print(type(lista))
# Out:
# ['Barcelona', 'Madrid', 'Valencia']
# <class 'list'>

# %%
type(football_cities[:'c'])
# Out:
# pandas.Series

# %%
#cast a ndarray
import numpy as np
cities = np.array(football_cities[:'c'])
print(cities)
print(type(cities))
# Out:
# ['Barcelona' 'Madrid' 'Valencia']
# <class 'numpy.ndarray'>

# %%
 # cas a dictionary
lista = dict(football_cities[:'c'])
print(lista)
# Out:
# {'a': 'Barcelona', 'b': 'Madrid', 'c': 'Valencia'}

# %%
# uso de masks para seleccionar
fibonacci = pd.Series([0, 1, 1, 2, 3, 5, 8, 13, 21])
print(fibonacci)

mask = fibonacci > 10
print(mask)
print(fibonacci[mask])

dst = pd.Series([13,21])
print(dst)

dst.equals(fibonacci)

fb = fibonacci[mask]
fb.reset_index(drop=True, inplace=True)
print(fb)

dst.equals(fb)
# Out:
# 0     0
# 1     1
# 2     1
# 3     2
# 4     3
# 5     5
# 6     8
# 7    13
# 8    21
# dtype: int64
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7     True
# 8     True
# dtype: bool
# 7    13
# 8    21
# dtype: int64
# 0    13
# 1    21
# dtype: int64
# 0    13
# 1    21
# dtype: int64
# True

# %%
# aplicar funciones de numpy a la serie
import numpy as np
print(np.sum(fibonacci))
# Out:
# 54

# %%
#filtrado con np.where
distances = pd.Series([12.1,np.nan,12.8,76.9,6.1,7.2])

valid_distances = np.where(pd.notnull(distances),distances,2)

print(valid_distances)
print(type(valid_distances))
# Out:
# [12.1  2.  12.8 76.9  6.1  7.2]
# <class 'numpy.ndarray'>

# %% [markdown]
# ## 3.0.1 Iteración

# %%
 # iterar sobre elementos
for value in fibonacci:
     print('Value: ' + str(value))
    
# # iterar sobre indices
for index in fibonacci.index:
    print('Index: ' + str(index))
# Out:
# Value: 0
# Value: 1
# Value: 1
# Value: 2
# Value: 3
# Value: 5
# Value: 8
# Value: 13
# Value: 21
# Index: 0
# Index: 1
# Index: 2
# Index: 3
# Index: 4
# Index: 5
# Index: 6
# Index: 7
# Index: 8

# %%
# iterar sobre elementos e índices al mismo tiempo
for index, value in fibonacci.items():
    print('Index: ' + str(index) + ' Value: ' + str(value))
# Out:
# Index: 0 Value: 0
# Index: 1 Value: 1
# Index: 2 Value: 1
# Index: 3 Value: 2
# Index: 4 Value: 3
# Index: 5 Value: 5
# Index: 6 Value: 8
# Index: 7 Value: 13
# Index: 8 Value: 21

# %%
for index, value in zip(fibonacci.index, fibonacci):
     print('Index: ' + str(index) + ' Value: ' + str(value))
# Out:
# Index: 0 Value: 0
# Index: 1 Value: 1
# Index: 2 Value: 1
# Index: 3 Value: 2
# Index: 4 Value: 3
# Index: 5 Value: 5
# Index: 6 Value: 8
# Index: 7 Value: 13
# Index: 8 Value: 21

# %% [markdown]
# ## 3.1 Series como diccionarios
# * Interpretar el índice como clave
# * Acepta operaciones para diccionarios

# %%
 # crear una serie a partir de un diccionario
serie = pd.Series( { 'Carlos' : 100, 'Marcos': 98} )

print(serie.index)
print(serie.values)

print(serie)
print(type(serie))
# Out:
# Index(['Carlos', 'Marcos'], dtype='str')
# [100  98]
# Carlos    100
# Marcos     98
# dtype: int64
# <class 'pandas.Series'>

# %%
# añade y elimina elementos a través de índices
serie['Pedro'] = 12
serie['Pedro']=15
del serie['Marcos']
print(serie)
# Out:
# Carlos    100
# Pedro      15
# dtype: int64

# %%
# query una serie
# print(serie['Marcos'])
if 'Marcos' in serie:
    print(serie['Marcos'])
    
print(serie)
# Out:
# Carlos    100
# Pedro      15
# dtype: int64

# %% [markdown]
# ## 3.2 Operaciones entre series

# %%
 # suma de dos series
# suma de valores con el mismo índice (NaN si no aparece en ambas)
serie1 = pd.Series([10,20,30,40], index=range(4) )
serie2 = pd.Series([1,2,3], index=range(3) )
suma = serie1 + serie2
print(suma)
# Out:
# 0    11.0
# 1    22.0
# 2    33.0
# 3     NaN
# dtype: float64

# %%
# resta de series (similar a la suma)
print(serie1 - serie2)
# Out:
# 0     9.0
# 1    18.0
# 2    27.0
# 3     NaN
# dtype: float64

# %%
# operaciones de pre-filtrado
result = serie1 + serie2
result[pd.isnull(result)] = 0 # mask con isnull()
print(result)
# Out:
# 0    11.0
# 1    22.0
# 2    33.0
# 3     0.0
# dtype: float64

# %% [markdown]
# ## 3.2.1 Diferencias entre Pandas Series y diccionario
# * Diccionario, es una estructura que relaciona las claves y los valores de forma arbitraria.
# * Series, estructura de forma estricta listas de valores con listas de índice asignado en la posición.
# * Series, es más eficiente para ciertas operaciones que los dicionarios.
# * En las Series los valores de entrada pueden ser listas o Numpy arrays.
# * En Series los índices semánticos pueden ser integers o caracteres, en los valores igual.
# * Series se podría entender entre una lista y un diccionario Python, pero es de una dimensión.
#
#
# ## 4 DataFrame
# * Datos tabulares (filas x columnas)
# * Columnas: Series con índices compartidos

# %%
 # crear un DataFrame a partir de un diccionario de elementos de la misma longitud
diccionario = { "Nombre" : ["Marisa","Laura","Manuel"],
                "Edad" : [34,29,12] }
print(diccionario)

# las claves identifican columnas
frame = pd.DataFrame(diccionario)
display(frame)
# Out:
# {'Nombre': ['Marisa', 'Laura', 'Manuel'], 'Edad': [34, 29, 12]}
#    Nombre  Edad
# 0  Marisa    34
# 1   Laura    29
# 2  Manuel    12

# %%
# crear un DataFrame a partir de un diccionario de elementos de la misma longitud
diccionario = { "Nombre" : ["Marisa","Laura","Manuel"],
                "Edad" : [34,29,12] }

# las claves identifican columnas
frame = pd.DataFrame(diccionario, index = ['a', 'b', 'c'])
display(frame)
# Out:
#    Nombre  Edad
# a  Marisa    34
# b   Laura    29
# c  Manuel    12

# %%
 # además de 'index', el parámetro 'columns' especifica el número y orden de las columnas
frame = pd.DataFrame(diccionario, columns = ['Nacionalidad', 'Nombre', 'Edad', 'Profesion','Genero'])
display(frame)
# Out:
#   Nacionalidad  Nombre  Edad Profesion Genero
# 0          NaN  Marisa    34       NaN    NaN
# 1          NaN   Laura    29       NaN    NaN
# 2          NaN  Manuel    12       NaN    NaN

# %%
 # acceso a columnas
nombres = frame['Nombre']
display(nombres)

print(type(nombres))
edades = frame['Edad']
display(edades)
print(type(edades))
# Out:
# 0    Marisa
# 1     Laura
# 2    Manuel
# Name: Nombre, dtype: str
# <class 'pandas.Series'>
# 0    34
# 1    29
# 2    12
# Name: Edad, dtype: int64
# <class 'pandas.Series'>

# %%
#siempre que el nombre de la columna lo permita (espacios, ...)
nombres = frame.Profesion
display(nombres)
type(nombres)
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# Name: Profesion, dtype: object
# pandas.Series

# %%
 # acceso al primer nombre del DataFrame frame??
print(frame['Nombre'][0])
print(frame.Nombre[0])
print(nombres[0])
# Out:
# Marisa
# Marisa
# nan

# %% [markdown]
# ## 4.0.1 Formas de crear un DataFrame
# * Con una Serie de pandas
# * Lista de diccionarios
# * Dicionario de Series de Pandas
# * Con un array de Numpy de dos dimensiones
# * Con array estructurado de Numpy
#
#
# ## 4.1 Modificar DataFrames

# %%
# añadir columnas
diccionario = { "Nombre" : ["Marisa","Laura","Manuel"],
                "Edad" : [34,29,12] }

frame = pd.DataFrame(diccionario, columns=['Nacionalidad', 'Nombre', 'Edad','Profesion', 'Direccion'])
frame['Direccion'] = 'Desconocida'
display(frame)
# Out:
#   Nacionalidad  Nombre  Edad Profesion    Direccion
# 0          NaN  Marisa    34       NaN  Desconocida
# 1          NaN   Laura    29       NaN  Desconocida
# 2          NaN  Manuel    12       NaN  Desconocida

# %%
lista_direcciones = ['Rue 13 del Percebe, 13', 'Evergreen Terrace, 3', 'Av de los Rombos, 12']

# %%
frame['Direccion'] = lista_direcciones
display(frame)
# Out:
#   Nacionalidad  Nombre  Edad Profesion               Direccion
# 0          NaN  Marisa    34       NaN  Rue 13 del Percebe, 13
# 1          NaN   Laura    29       NaN    Evergreen Terrace, 3
# 2          NaN  Manuel    12       NaN    Av de los Rombos, 12

# %%
 # añadir fila (requiere todos los valores)
user_2 = ['Alemania','Klaus',20, 'none','Desconocida']
frame.loc[3] = user_2
display(frame)
# Out:
#   Nacionalidad  Nombre  Edad Profesion               Direccion
# 0          NaN  Marisa    34       NaN  Rue 13 del Percebe, 13
# 1          NaN   Laura    29       NaN    Evergreen Terrace, 3
# 2          NaN  Manuel    12       NaN    Av de los Rombos, 12
# 3     Alemania   Klaus    20      none             Desconocida

# %%
# eliminar fila (similar a Series)
frame = pd.DataFrame(diccionario,columns=['Nacionalidad', 'Nombre', 'Edad', 'Profesion'])
frame = frame.drop(2) # por qué necesitamos reasignar el frame?
display(frame)

frame.drop('Nombre', axis = 1, inplace = True)
display(frame)
# Out:
#   Nacionalidad  Nombre  Edad Profesion
# 0          NaN  Marisa    34       NaN
# 1          NaN   Laura    29       NaN
#   Nacionalidad  Edad Profesion
# 0          NaN    34       NaN
# 1          NaN    29       NaN

# %%
#eliminar columna
del frame['Profesion']
display(frame)
# Out:
#   Nacionalidad  Edad
# 0          NaN    34
# 1          NaN    29

# %%
 # acceder a la traspuesta (como una matriz)
display(frame.T)
# Out:
#                 0    1
# Nacionalidad  NaN  NaN
# Edad           34   29

# %% [markdown]
# ## 4.2 Iteración

# %%
 # iteración sobre el DataFrame?
frame = pd.DataFrame(diccionario, columns=['Nacionalidad', 'Nombre', 'Edad', 'Profesion'])
display(frame)

for a in frame:
    print(a) # qué es 'a'?
    print(type(a))
# Out:
#   Nacionalidad  Nombre  Edad Profesion
# 0          NaN  Marisa    34       NaN
# 1          NaN   Laura    29       NaN
# 2          NaN  Manuel    12       NaN
# Nacionalidad
# <class 'str'>
# Nombre
# <class 'str'>
# Edad
# <class 'str'>
# Profesion
# <class 'str'>

# %%
# iteracion sobre filas
for value in frame.values:
    print(value)
    print(type(value))
# Out:
# [nan 'Marisa' 34 nan]
# <class 'numpy.ndarray'>
# [nan 'Laura' 29 nan]
# <class 'numpy.ndarray'>
# [nan 'Manuel' 12 nan]
# <class 'numpy.ndarray'>

# %%
# iterar sobre filas y luego sobre cada valor?
for values in frame.values:
    for value in values:
         print(value)
# Out:
# nan
# Marisa
# 34
# nan
# nan
# Laura
# 29
# nan
# nan
# Manuel
# 12
# nan

# %% [markdown]
# ## 4.3 Indexación y slicing con DataFrames

# %%
d1 = {'ciudad':'Valencia', 'temperatura':10, 'o2':1}
d2 = {'ciudad':'Barcelona', 'temperatura':8}
d3 = {'ciudad':'Valencia', 'temperatura':9}
d4 = {'ciudad':'Madrid', 'temperatura':10, 'humedad':80}
d5 = {'ciudad':'Sevilla', 'temperatura':15, 'humedad':50, 'co2':6}
d6 = {'ciudad':'Valencia', 'temperatura':10, 'humedad':90, 'co2':10}

ls_data = [d1, d2, d3, d4, d5, d6] # lista de diccionarios
df_data = pd.DataFrame(ls_data, index = list('abcdef'))
display(df_data)
# Out:
#       ciudad  temperatura   o2  humedad   co2
# a   Valencia           10  1.0      NaN   NaN
# b  Barcelona            8  NaN      NaN   NaN
# c   Valencia            9  NaN      NaN   NaN
# d     Madrid           10  NaN     80.0   NaN
# e    Sevilla           15  NaN     50.0   6.0
# f   Valencia           10  NaN     90.0  10.0

# %%
# Acceso a un valor concreto por indice posicional [row, col]
print(df_data.iloc[1,1])

# Acceso a todos los valores hasta un índice por enteros
display(df_data.iloc[:3,:4])

# Acceso a datos de manera explícita, indice semantico (se incluyen)
display(df_data.loc['a', 'temperatura'])
display(df_data.loc[:'c', :'o2'])
display(df_data.loc[:'c', 'temperatura':'o2'])

display(df_data.loc[:, ['ciudad','o2']])
# Out:
# 8
#       ciudad  temperatura   o2  humedad
# a   Valencia           10  1.0      NaN
# b  Barcelona            8  NaN      NaN
# c   Valencia            9  NaN      NaN
# np.int64(10)
#       ciudad  temperatura   o2
# a   Valencia           10  1.0
# b  Barcelona            8  NaN
# c   Valencia            9  NaN
#    temperatura   o2
# a           10  1.0
# b            8  NaN
# c            9  NaN
#       ciudad   o2
# a   Valencia  1.0
# b  Barcelona  NaN
# c   Valencia  NaN
# d     Madrid  NaN
# e    Sevilla  NaN
# f   Valencia  NaN

# %%
# indexación con nombre de columna (por columnas)
print(df_data['ciudad']) # --> Series

display(df_data[['ciudad', 'o2']])
# Out:
# a     Valencia
# b    Barcelona
# c     Valencia
# d       Madrid
# e      Sevilla
# f     Valencia
# Name: ciudad, dtype: str
#       ciudad   o2
# a   Valencia  1.0
# b  Barcelona  NaN
# c   Valencia  NaN
# d     Madrid  NaN
# e    Sevilla  NaN
# f   Valencia  NaN

# %%
# indexación con índice posicional (no permitido!). Esto busca columna.
df_data[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\Trabajos_Machine_2026\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
# --> 176 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:583, in pandas._libs.index.StringObjectEngine._check_type()
# --> 583 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[57], line 2
#       1 # indexación con índice posicional (no permitido!). Esto busca columna.
# ----> 2 df_data[0]
#
# File ~\anaconda3\envs\Trabajos_Machine_2026\Lib\site-packages\pandas\core\frame.py:4378, in DataFrame.__getitem__(self, key)
#    4374
#    4375         if is_single_key:
#    4376             if self.columns.nlevels > 1:
#    4377                 return self._getitem_multilevel(key)
# -> 4378             indexer = self.columns.get_loc(key)
#    4379             if is_integer(indexer):
#    4380                 indexer = [indexer]
#    4381         else:
#
# File ~\anaconda3\envs\Trabajos_Machine_2026\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 0

# %%
# indexar por posición con 'iloc'
print(df_data.iloc[0]) # --> Series de la primera fila (qué marca los índces)
# Out:
# ciudad         Valencia
# temperatura          10
# o2                  1.0
# humedad             NaN
# co2                 NaN
# Name: a, dtype: object

# %%
# indexar semántico con 'loc'
df_data.loc['a'] # --> Series de la fila con índice 'a'
# Out:
# ciudad         Valencia
# temperatura          10
# o2                  1.0
# humedad             NaN
# co2                 NaN
# Name: a, dtype: object

# %%
# indexar semántico con 'loc'
df_data.loc[:'b'] # --> DataFrame de la fila con índice 'a' y 'b'
# Out:
#       ciudad  temperatura   o2  humedad  co2
# a   Valencia           10  1.0      NaN  NaN
# b  Barcelona            8  NaN      NaN  NaN

# %%
df_data.loc[:'b'].loc[:,["o2", "humedad"]] # slicing anidado
# Out:
#     o2  humedad
# a  1.0      NaN
# b  NaN      NaN

# %%
 # si se modifica una porcion del dataframe se modifica el dataframe original (referencia)
display(df_data)

serie = df_data.loc['a']
print(serie)
serie.iloc[2] = 3000 # setting with copy warning!!!
display(df_data)

# copiar data frame
df_2 = df_data.loc['a'].copy()

df_2.iloc[2] = 3000
display(df_2)
display(df_data)
# Out:
#       ciudad  temperatura   o2  humedad   co2
# a   Valencia           10  1.0      NaN   NaN
# b  Barcelona            8  NaN      NaN   NaN
# c   Valencia            9  NaN      NaN   NaN
# d     Madrid           10  NaN     80.0   NaN
# e    Sevilla           15  NaN     50.0   6.0
# f   Valencia           10  NaN     90.0  10.0
# ciudad         Valencia
# temperatura          10
# o2                  1.0
# humedad             NaN
# co2                 NaN
# Name: a, dtype: object
#       ciudad  temperatura   o2  humedad   co2
# a   Valencia           10  1.0      NaN   NaN
# b  Barcelona            8  NaN      NaN   NaN
# c   Valencia            9  NaN      NaN   NaN
# d     Madrid           10  NaN     80.0   NaN
# e    Sevilla           15  NaN     50.0   6.0
# f   Valencia           10  NaN     90.0  10.0
# ciudad         Valencia
# temperatura          10
# o2                 3000
# humedad             NaN
# co2                 NaN
# Name: a, dtype: object
#       ciudad  temperatura   o2  humedad   co2
# a   Valencia           10  1.0      NaN   NaN
# b  Barcelona            8  NaN      NaN   NaN
# c   Valencia            9  NaN      NaN   NaN
# d     Madrid           10  NaN     80.0   NaN
# e    Sevilla           15  NaN     50.0   6.0
# f   Valencia           10  NaN     90.0  10.0

# %%
# ambos aceptan 'axis' como argumento
# df_data.iloc(axis=1)[0] # --> todos los valores asignados a la primera columna 'ciudad'
df_data.loc(axis=1)['ciudad'] # --> equivalente frame['ciudad']
# Out:
# a     Valencia
# b    Barcelona
# c     Valencia
# d       Madrid
# e      Sevilla
# f     Valencia
# Name: ciudad, dtype: str

# %%
# qué problema puede tener este fragmento?
frame = pd.DataFrame({"Name" : ['Carlos','Pedro'], "Age" : [34,22]}, index=[1,0])
display(frame)
# Out:
#      Name  Age
# 1  Carlos   34
# 0   Pedro   22

# %%
 # por defecto, pandas interpreta índice posicional --> error en frames
# cuando hay posible ambigüedad, utilizar loc y iloc
print('Primera fila\n')
print(frame.iloc[0])
print('\nElemento con index 0\n')
print(frame.loc[0])
# Out:
# Primera fila
#
# Name    Carlos
# Age         34
# Name: 1, dtype: object
#
# Elemento con index 0
#
# Name    Pedro
# Age        22
# Name: 0, dtype: object

# %% [markdown]
# ## 4.4 Objeto Index de Pandas

# %%
# Contrucción de índices
ind = pd.Index([2, 3, 5, 23, 26])
# recuperar datos
print(ind[3])
print(ind[::2])
# Out:
# 23
# Index([2, 5, 26], dtype='int64')

# %%
# usar un objeto index al crear dataframe
frame = pd.DataFrame({"Name" : ['Carlos','Pedro', 'Manolo', 'Luis', 'Alberto'], "Age" : [34,22,15,55,23]}, index=ind)
display(frame)
# Out:
#        Name  Age
# 2    Carlos   34
# 3     Pedro   22
# 5    Manolo   15
# 23     Luis   55
# 26  Alberto   23

# %%
# Son inmutables! No se modifican los datos.
ind[3] = 8
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 2
#       1 # Son inmutables! No se modifican los datos.
# ----> 2 ind[3] = 8
#
# File ~\anaconda3\envs\Trabajos_Machine_2026\Lib\site-packages\pandas\core\indexes\base.py:5382, in Index.__setitem__(self, key, value)
#    5380 @final
#    5381 def __setitem__(self, key, value) -> None:
# -> 5382     raise TypeError("Index does not support mutable operations")
#
# TypeError: Index does not support mutable operations

# %%
# change index column
frame = pd.DataFrame({"Name" : ['Carlos','Pedro', 'Manolo', 'Luis', 'Alberto'], "Age" : [34,22,15,55,23]}, index=ind)
display(frame)
frame.set_index('Age', inplace=True)
display(frame)
# Out:
#        Name  Age
# 2    Carlos   34
# 3     Pedro   22
# 5    Manolo   15
# 23     Luis   55
# 26  Alberto   23
#         Name
# Age
# 34    Carlos
# 22     Pedro
# 15    Manolo
# 55      Luis
# 23   Alberto

# %% [markdown]
# ## 4.5 Slicing

# %%
# slice por filas
d_and_d_characters = {'Name' : ['bundenth','theorin','barlok'], 'Strength' : [10,12,19], 'Wisdom' : [20,13,6]}
character_data = pd.DataFrame(d_and_d_characters, index=['a','b','c'])
display(character_data)
display(character_data[:-1])
display(character_data[1:2])
# Out:
#        Name  Strength  Wisdom
# a  bundenth        10      20
# b   theorin        12      13
# c    barlok        19       6
#        Name  Strength  Wisdom
# a  bundenth        10      20
# b   theorin        12      13
#       Name  Strength  Wisdom
# b  theorin        12      13

# %%
 # slicing para columnas
display(character_data[['Name','Wisdom']])
# Out:
#        Name  Wisdom
# a  bundenth      20
# b   theorin      13
# c    barlok       6

# %%
#slicing con 'loc' e 'iloc'
display(character_data.iloc[1:])
display(character_data.loc[:'b','Name':'Strength'])
# Out:
#       Name  Strength  Wisdom
# b  theorin        12      13
# c   barlok        19       6
#        Name  Strength
# a  bundenth        10
# b   theorin        12

# %% [markdown]
# ¿Cómo filtrar filas y columnas? Por ejemplo, para todos los personajes, obtener ‘Name’ y ‘Strength’

# %%
# usando 'loc' para hacer slicing
display(character_data.loc[:,'Name':'Strength'])
# Out:
#        Name  Strength
# a  bundenth        10
# b   theorin        12
# c    barlok        19

# %%
# usando 'loc' para buscar específicamente filas y columnas
display(character_data.loc[ ['a','c'], ['Name','Wisdom'] ])
# Out:
#        Name  Wisdom
# a  bundenth      20
# c    barlok       6

# %%
# lo mismo con 'iloc'?
display(character_data.iloc[[0,2],[0,2]])
display(character_data.iloc[[0,-1],[0,-1]])
# Out:
#        Name  Wisdom
# a  bundenth      20
# c    barlok       6
#        Name  Wisdom
# a  bundenth      20
# c    barlok       6

# %%
# lista de los personajes con el atributo Strength > 11
display(character_data.loc[character_data['Strength'] > 11, ['Name', 'Strength']])
# Out:
#       Name  Strength
# b  theorin        12
# c   barlok        19

# %%
# listar los personajes con Strength > 15 o Wisdom > 15
display(character_data.loc[(character_data['Strength'] > 15) | (character_data['Wisdom'] > 15)])
# Out:
#        Name  Strength  Wisdom
# a  bundenth        10      20
# c    barlok        19       6

# %%
## 5 Cargar y guardar datos en pandas

# %%
# Guardar a csv
import os
ruta = os.path.join("res" ,"o_d_d_characters.csv")
#character_data.to_csv(ruta, sep=';') # sep por defecto: ','

# %%
loaded = pd.read_csv(ruta, sep=';')
display(loaded)
# Out:
#   Unnamed: 0      Name  Strength  Wisdom
# 0          a  bundenth        10      20
# 1          b   theorin        12      13
# 2          c    barlok        19       6

# %%
ruta = os.path.join("res","titanic.csv")

# %%
titanic = pd.read_csv(ruta, sep=',')
display(titanic)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
loaded = pd.read_csv(ruta, sep=',', index_col = 0)
display(loaded)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
# ...            ...    ...               ...      ...   ...      ...
# 887              0      0            211536  13.0000   NaN        S
# 888              0      0            112053  30.0000   B42        S
# 889              1      2        W./C. 6607  23.4500   NaN        S
# 890              0      0            111369  30.0000  C148        C
# 891              0      0            370376   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %% [markdown]
# otros argumentos to_csv()
# * na_rep=‘string’ –> representar valores NaN en el archivo csv
#
# otros argumentos read_csv()
# * na_values=‘string’
# Pandas también ofrece funciones para leer/guardar a otros formatos estándares: JSON, HDF5 o
# Excel en su [API](https://pandas.pydata.org/pandas-docs/stable/reference/io.html)

# %% [markdown]
# ## 6 Ejemplo práctico en pandas
# * [MovieLens dataset](https://grouplens.org/datasets/movielens/)
# * Reviews de películas
# * 1 millón de entradas
# * Datos demográficos de usuarios

# %%
import numpy as np
import pandas as pd
import zipfile # para descomprimir archivos zip
import urllib.request # para descargar de URL
import os
# descargar MovieLens dataset
url = 'http://files.grouplens.org/datasets/movielens/ml-1m.zip'
ruta = os.path.join("res", "ml-1m.zip")
urllib.request.urlretrieve(url, ruta)
# Out:
# ---------------------------------------------------------------------------
# ContentTooShortError                      Traceback (most recent call last)
# Cell In[85], line 9
#       5 import os
#       6 # descargar MovieLens dataset
#       7 url = 'http://files.grouplens.org/datasets/movielens/ml-1m.zip'
#       8 ruta = os.path.join("res", "ml-1m.zip")
# ----> 9 urllib.request.urlretrieve(url, ruta)
#
# File ~\anaconda3\envs\Trabajos_Machine_2026\Lib\urllib\request.py:280, in urlretrieve(url, filename, reporthook, data)
#     277                 reporthook(blocknum, bs, size)
#     279 if size >= 0 and read < size:
# --> 280     raise ContentTooShortError(
#     281         "retrieval incomplete: got only %i out of %i bytes"
#     282         % (read, size), result)
#     284 return result
#
# ContentTooShortError: <urlopen error retrieval incomplete: got only 1591947 out of 5917549 bytes>

# %%
# descomprimiendo archivo zip
ruta_ext = os.path.join("res")
with zipfile.ZipFile(ruta, 'r') as z:
     print('Extracting all files...')
     z.extractall(ruta_ext) # destino
     print('Done!')
# take a look at readme y revisar formatos

# %%
ruta_users = os.path.join("res", "ml-1m", "users.dat")
users_dataset = pd.read_csv(ruta_users, sep='::', index_col=0, engine='python')
display(users_dataset)

# %%
# Varios problemas
# sin cabecera! primer valor se ha perdido
# las columnas no tienen nombres
pd.read_csv?

# %%
 # especificar nombres, cargar sin cabecera
users_dataset = pd.read_csv(ruta_users, sep='::', index_col=0,
header=None, names=['UserID','Gender','Age','Occupation','Zip-code'], engine='python')
display(users_dataset)

# %%
# samplear la tabla
display(users_dataset.sample(10))

# %%
# samplear la cabeza
display(users_dataset.head(4))

# %%
# samplear la cola
display(users_dataset.tail(10))

# %%
# tipos de datos sobre las columnas
users_dataset.dtypes

# %%
display(users_dataset[users_dataset['Zip-code'].str.len() > 5])

# %%
# información general sobre atributos numéricos
display(users_dataset.describe())

# %%
users_dataset.info()

# %%
# incluir otros atributos (no todo tiene sentido)
display(users_dataset.describe(include='all'))

# %%
# cuántos usuarios son mujeres (Gender='F')
len(users_dataset[users_dataset['Gender'] == 'F'])
#select count(*) from users_dataset where users_dataset.Gender = 'F'

# %%
# mostrar solo los menores de edad
under_age = users_dataset[users_dataset['Age'] == 1]
print(len(under_age))
display(under_age.sample(10))

# %%
# filtrar edad incorrecta (míninimo 18) SettingWithCopyWarning!!!
users_dataset = pd.read_csv(ruta_users, sep='::', index_col=0,
    header=None, names=['UserID','Gender','Age','Occupation','Zip-code'], engine='python')
under_age = users_dataset[users_dataset['Age'] == 1]

under_age.loc['Age'] = np.nan
display(under_age.head())
# users_dataset[users_dataset['Age'] < 18] = under_age
# display(users_dataset)

# %%
# filtrar edad incorrecta (míninimo 18) Fixing it by Copying the slice
users_dataset = pd.read_csv(ruta_users, sep='::', index_col=0,
header=None, names=['UserID','Gender','Age','Occupation','Zip-code'], engine='python')
under_age = users_dataset[users_dataset['Age'] == 1]
under_age_copy = under_age.copy()

display(under_age_copy.head())
under_age_copy['Age'] = np.nan

display(under_age_copy.head())
users_dataset[users_dataset['Age'] == 1] = under_age_copy # sets the rows according to the indexes
display(users_dataset.head())

# %%
# filtrar edad incorrecta (míninimo 18) Remove them from the dataset
users_dataset = pd.read_csv(ruta_users, sep='::', index_col=0,
header=None, names=['UserID','Gender','Age','Occupation','Zip-code'], engine='python')

display(users_dataset[users_dataset['Age'] == 1].head(4))

users_dataset.loc[users_dataset['Age'] == 1, 'Age'] = np.nan
display(users_dataset)

display(users_dataset.loc[pd.isnull(users_dataset['Age'])].head(4))

users_dataset.drop(users_dataset[pd.isnull(users_dataset['Age'])].index, inplace = True)
display(users_dataset.head(4))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[86], line 2
#       1 # filtrar edad incorrecta (míninimo 18) Remove them from the dataset
# ----> 2 users_dataset = pd.read_csv(ruta_users, sep='::', index_col=0,
#       3 header=None, names=['UserID','Gender','Age','Occupation','Zip-code'], engine='python')
#       4
#       5 display(users_dataset[users_dataset['Age'] == 1].head(4))
#
# NameError: name 'ruta_users' is not defined

# %%
# Agrupar datos por atributos
display(users_dataset.groupby(by='Gender').describe())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[87], line 2
#       1 # Agrupar datos por atributos
# ----> 2 display(users_dataset.groupby(by='Gender').describe())
#
# NameError: name 'users_dataset' is not defined

# %%
# Grabar la tabla modificada
# Cambiar el separador a ','
# Guardar NaN como 'null'
ruta_output = os.path.join('res', 'ml-1m', 'o_users_processed.csv')
users_dataset.to_csv(ruta_output, sep=',',na_rep='null')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[88], line 5
#       1 # Grabar la tabla modificada
#       2 # Cambiar el separador a ','
#       3 # Guardar NaN como 'null'
#       4 ruta_output = os.path.join('res', 'ml-1m', 'o_users_processed.csv')
# ----> 5 users_dataset.to_csv(ruta_output, sep=',',na_rep='null')
#
# NameError: name 'users_dataset' is not defined

# %% [markdown]
# ## 7 Ejercicios
# * Hacer un análisis general de los otros dos archivos CSV en ml-1m (‘movies.dat’ y ‘ratings.dat’)
# * Analizando el dataset ratings.dat, ¿hay algún usuario que no tenga ninguna review? ¿Cuántos
# tienen menos de 30 reviews?

# %%
 # especificar nombres, cargar sin cabecera
import os
import pandas as pd
ruta_ratings = os.path.join("res", "ml-1m", "ratings.dat")

ratings_dataset = pd.read_csv(ruta_ratings, sep='::',
header=None, names=['UserID','MovieID','Rating','Timestamp'], engine='python')
display(ratings_dataset)
# Out:
#          UserID  MovieID  Rating  Timestamp
# 0             1     1193       5  978300760
# 1             1      661       3  978302109
# 2             1      914       3  978301968
# 3             1     3408       4  978300275
# 4             1     2355       5  978824291
# ...         ...      ...     ...        ...
# 1000204    6040     1091       1  956716541
# 1000205    6040     1094       5  956704887
# 1000206    6040      562       5  956704746
# 1000207    6040     1096       4  956715648
# 1000208    6040     1097       4  956715569
#
# [1000209 rows x 4 columns]

# %%
# hay algún usuario que no tenga ninguna review
n_users_with_reviews = len(ratings_dataset.groupby(by='UserID'))
print(n_users_with_reviews)
n_users = len(users_dataset)
print(n_users)
print(n_users - n_users_with_reviews)
# Out:
# 6040
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[90], line 4
#       1 # hay algún usuario que no tenga ninguna review
#       2 n_users_with_reviews = len(ratings_dataset.groupby(by='UserID'))
#       3 print(n_users_with_reviews)
# ----> 4 n_users = len(users_dataset)
#       5 print(n_users)
#       6 print(n_users - n_users_with_reviews)
#
# NameError: name 'users_dataset' is not defined

# %%
# Cuántos tienen menos de 30 reviews
ratings_under_30 = ratings_dataset.groupby(['UserID'])['UserID'].filter(lambda x: len(x) < 30).value_counts()
display(ratings_under_30)
print(len(ratings_under_30))
# Out:
# UserID
# 71      29
# 221     29
# 234     29
# 246     29
# 282     29
#         ..
# 5533    20
# 5725    20
# 5828    20
# 5904    20
# 6038    20
# Name: count, Length: 751, dtype: int64
# 751
