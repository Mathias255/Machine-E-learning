# %% [markdown]
# ![logo](img/logoitqv1.jpg)
# <br>
# # 0.1 01MIAR - Estructuras de datos, +Pandas
#
# <br>
#
# ![python](img/python_logo.png)
#
# <br>
#
# *Alexis González*
#
# <br>
#
# [link de Git Hub](https://github.com/Mathias255/Machine-E-learning.git)

# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '3.0.3'

# %% [markdown]
# ## 1 Operaciones en pandas
#
# **Búsqueda**

# %%
rand_matrix = np.random.randint(6,size=(2,3))
frame = pd.DataFrame(rand_matrix , columns=list('ABC'))
display(frame)
# Out:
#    A  B  C
# 0  3  0  3
# 1  1  3  1

# %%
# buscando columnas (DataFrame como dic, busca en claves)
'A' in frame
# Out:
# True

# %%
# buscando valores
display(frame.isin([3,2])) # --> mask de respuesta (valores que son 3 o 2)
# Out:
#        A      B      C
# 0   True  False   True
# 1  False   True  False

# %%
# Contar el número de ocurrencias
print(frame.isin([4]).values.sum())
display(frame.isin([4])) #devuelve una mask con valores true si el elemento es 4
print(frame.isin([4]).values)
type(frame.isin([4]).values) # pandas es una capa alrededor de numpy
# Out:
# 0
#        A      B      C
# 0  False  False  False
# 1  False  False  False
# [[False False False]
#  [False False False]]
# numpy.ndarray

# %%
# Cuántos valores son >= 2
mask = frame >= 2
print(mask.values.sum())
display(mask)
# Out:
# 3
#        A      B      C
# 0   True  False   True
# 1  False   True  False

# %% [markdown]
# **Ordenación**

# %%
from random import shuffle

rand_matrix = np.random.randint(20,size=(5,4))

indices = list(range(5))
shuffle(indices) # mezcla indices

frame = pd.DataFrame(rand_matrix , columns=list('DACB'), index=indices)
display(frame)
# Out:
#     D   A   C  B
# 1  19  11  15  1
# 2  13   9   2  6
# 4   7  18  14  5
# 3   4   6  14  8
# 0   5   5   8  6

# %%
# ordenar por índice
display(frame.sort_index(ascending=False))
display(frame)
# Out:
#     D   A   C  B
# 4   7  18  14  5
# 3   4   6  14  8
# 2  13   9   2  6
# 1  19  11  15  1
# 0   5   5   8  6
#     D   A   C  B
# 1  19  11  15  1
# 2  13   9   2  6
# 4   7  18  14  5
# 3   4   6  14  8
# 0   5   5   8  6

# %%
#ordenar por columna
display(frame.sort_index(axis=1, ascending=False))
# Out:
#     D   C  B   A
# 1  19  15  1  11
# 2  13   2  6   9
# 4   7  14  5  18
# 3   4  14  8   6
# 0   5   8  6   5

# %%
# ordenar filas por valor en columna
display(frame.sort_values(by='A', ascending=True))
# Out:
#     D   A   C  B
# 0   5   5   8  6
# 3   4   6  14  8
# 2  13   9   2  6
# 1  19  11  15  1
# 4   7  18  14  5

# %%
# ordenar columnas por valor en fila
display(frame.sort_values(by=1, axis=1, ascending=True))
# Out:
#    B   A   C   D
# 1  1  11  15  19
# 2  6   9   2  13
# 4  5  18  14   7
# 3  8   6  14   4
# 0  6   5   8   5

# %%
# ordenar por valor en columna y guardar cambios
frame.sort_values(by='A', ascending=False, inplace=True)
display(frame)
# Out:
#     D   A   C  B
# 4   7  18  14  5
# 1  19  11  15  1
# 2  13   9   2  6
# 3   4   6  14  8
# 0   5   5   8  6

# %% [markdown]
# **Ranking**
# * Construir un ranking de valores

# %%
display(frame)
# Out:
#     D   A   C  B
# 4   7  18  14  5
# 1  19  11  15  1
# 2  13   9   2  6
# 3   4   6  14  8
# 0   5   5   8  6

# %%
display(frame.rank(method='max', axis=1))
# Out:
#      D    A    C    B
# 4  2.0  4.0  3.0  1.0
# 1  4.0  2.0  3.0  1.0
# 2  4.0  3.0  1.0  2.0
# 3  1.0  2.0  4.0  3.0
# 0  2.0  2.0  4.0  3.0

# %%
# Imprimir, uno a uno, los valores de la columna 'C' de mayor a menor
for x in frame.sort_values(by='C', ascending=False)['C'].values:
    print(x)
# Out:
# 15
# 14
# 14
# 8
# 2

# %% [markdown]
# ## 2 Operaciones
# Operaciones matemáticas entre objetos

# %%
matrixA = np.random.randint(100,size=(4,4))
matrixB = np.random.randint(100,size=(4,4))
frameA = pd.DataFrame(matrixA)
frameB = pd.DataFrame(matrixB)
display(frameA)
display(frameB)
# Out:
#     0   1   2   3
# 0   0  57  96  43
# 1  28  36  62  81
# 2  67  42  75  99
# 3   5  13   9   3
#     0   1   2   3
# 0  79  44  43  92
# 1  47  76  92  37
# 2  84  97  96  77
# 3  30  97  22  61

# %%
# a través de métodos u operadores
display(frameA + frameB == frameA.add(frameB))
display(frameA + frameB)
# Out:
#       0     1     2     3
# 0  True  True  True  True
# 1  True  True  True  True
# 2  True  True  True  True
# 3  True  True  True  True
#      0    1    2    3
# 0   79  101  139  135
# 1   75  112  154  118
# 2  151  139  171  176
# 3   35  110   31   64

# %%
display(frameB - frameA == frameB.sub(frameA))
display(frameB - frameA)
# Out:
#       0     1     2     3
# 0  True  True  True  True
# 1  True  True  True  True
# 2  True  True  True  True
# 3  True  True  True  True
#     0   1   2   3
# 0  79 -13 -53  49
# 1  19  40  30 -44
# 2  17  55  21 -22
# 3  25  84  13  58

# %%
 # si los frames no son iguales, valor por defecto NaN
frameC = pd.DataFrame(np.random.randint(100,size=(3,3)))
display(frameA)
display(frameC)
display(frameC + frameA)
# Out:
#     0   1   2   3
# 0   0  57  96  43
# 1  28  36  62  81
# 2  67  42  75  99
# 3   5  13   9   3
#     0   1   2
# 0  90  50  22
# 1  42  63  70
# 2  73  29  43
#        0      1      2   3
# 0   90.0  107.0  118.0 NaN
# 1   70.0   99.0  132.0 NaN
# 2  140.0   71.0  118.0 NaN
# 3    NaN    NaN    NaN NaN

# %%
# se puede especificar el valor por defecto con el argumento fill_value
display(frameA.add(frameC, fill_value=0))
# Out:
#        0      1      2     3
# 0   90.0  107.0  118.0  43.0
# 1   70.0   99.0  132.0  81.0
# 2  140.0   71.0  118.0  99.0
# 3    5.0   13.0    9.0   3.0

# %% [markdown]
# Operadores aritméticos solo válidos en elementos aceptables

# %%
frameD = pd.DataFrame({0: ['a','b'],1:['d','f']})
display(frameD)
frameA - frameD
# Out:
#    0  1
# 0  a  d
# 1  b  f
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 3
#       1 frameD = pd.DataFrame({0: ['a','b'],1:['d','f']})
#       2 display(frameD)
# ----> 3 frameA - frameD
#
# File ~\anaconda3\envs\Trabajos_Machine_2026\Lib\site-packages\pandas\core\ops\common.py:85, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      82     other = sanitize_array(other, None)
#      83     other = ensure_wrapped_if_datetimelike(other)
# ---> 85 return method(self, other)
#
# File ~\anaconda3\envs\Trabajos_Machine_2026\Lib\site-packages\pandas\core\arraylike.py:198, in OpsMixin.__sub__(self, other)
#     196 @unpack_zerodim_and_defer("__sub__")
#     197 def __sub__(self, other):
# --> 198     return self._arith_method(other, operator.sub)
#
# File ~\anaconda3\envs\Trabajos_Machine_2026\Lib\site-packages\pandas\core\frame.py:9143, in DataFrame._arith_method(self, other, op)
#    9141     def _arith_method(self, other, op):
#    9142         if self._should_reindex_frame_op(other, op, 1, None, None):
# -> 9143             return self._arith_method_with_reindex(other, op)
#    9144
#    9145         axis: Literal[1] = 1  # only relevant for Series other case
#    9146         other = ops.maybe_prepare_scalar_for_op(other, (self.shape[axis],))
#
# File ~\anaconda3\envs\Trabajos_Machine_2026\Lib\site-packages\pandas\core\frame.py:9279, in DataFrame._arith_method_with_reindex(self, right, op)
#    9275             new_right = new_right.copy(deep=False)
#    9276             new_left.columns = cols
#    9277             new_right.columns = cols
#    9278
# -> 9279         result = op(new_left, new_right)
#    9280
#    9281         # Do the join on the columns instead of using left._align_for_op
#    9282         #  to avoid constructing two potentially large/sparse DataFrames
#
# File ~\anaconda3\envs\Trabajos_Machine_2026\Lib\site-packages\pandas\core\ops\common.py:85, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      82     other = sanitize_array(other, None)
#      83     other = ensure_wrapped_if_datetimelike(other)
# ---> 85 return method(self, other)
#
# File ~\anaconda3\envs\Trabajos_Machine_2026\Lib\site-packages\pandas\core\arraylike.py:198, in OpsMixin.__sub__(self, other)
#     196 @unpack_zerodim_and_defer("__sub__")
#     197 def __sub__(self, other):
# --> 198     return self._arith_method(other, operator.sub)
#
# File ~\anaconda3\envs\Trabajos_Machine_2026\Lib\site-packages\pandas\core\frame.py:9151, in DataFrame._arith_method(self, other, op)
#    9147
#    9148         self, other = self._align_for_op(other, axis, flex=True, level=None)
#    9149
#    9150         with np.errstate(all="ignore"):
# -> 9151             new_data = self._dispatch_frame_op(other, op, axis=axis)
#    9152         return self._construct_result(new_data, other=other)
#
# File ~\anaconda3\envs\Trabajos_Machine_2026\Lib\site-packages\pandas\core\frame.py:9194, in DataFrame._dispatch_frame_op(self, right, func, axis)
#    9190             #  fails in cases with empty columns reached via
#    9191             #  _frame_arith_method_with_reindex
#    9192
#    9193             # TODO operate_blockwise expects a manager of the same type
# -> 9194             bm = self._mgr.operate_blockwise(
#    9195                 right._mgr,
#    9196                 array_op,
#    9197             )
#
# File ~\anaconda3\envs\Trabajos_Machine_2026\Lib\site-packages\pandas\core\internals\managers.py:1691, in BlockManager.operate_blockwise(self, other, array_op)
#    1687 def operate_blockwise(self, other: BlockManager, array_op) -> BlockManager:
#    1688     """
#    1689     Apply array_op blockwise with another (aligned) BlockManager.
#    1690     """
# -> 1691     return operate_blockwise(self, other, array_op)
#
# File ~\anaconda3\envs\Trabajos_Machine_2026\Lib\site-packages\pandas\core\internals\ops.py:65, in operate_blockwise(left, right, array_op)
#      63 res_blks: list[Block] = []
#      64 for lvals, rvals, locs, left_ea, right_ea, rblk in _iter_block_pairs(left, right):
# ---> 65     res_values = array_op(lvals, rvals)
#      66     if (
#      67         left_ea
#      68         and not right_ea
#      69         and hasattr(res_values, "reshape")
#      70         and not is_1d_only_ea_dtype(res_values.dtype)
#      71     ):
#      72         res_values = res_values.reshape(1, -1)
#
# File ~\anaconda3\envs\Trabajos_Machine_2026\Lib\site-packages\pandas\core\ops\array_ops.py:279, in arithmetic_op(left, right, op)
#     270 right = ensure_wrapped_if_datetimelike(right)
#     272 if (
#     273     should_extension_dispatch(left, right)
#     274     or isinstance(right, (Timedelta, BaseOffset, Timestamp))
#    (...)    277     # Timedelta/Timestamp and other custom scalars are included in the check
#     278     # because numexpr will fail on it, see GH#31457
# --> 279     res_values = op(left, right)
#     280 else:
#     281     # TODO we should handle EAs consistently and move this check before the if/else
#     282     # (https://github.com/pandas-dev/pandas/issues/41165)
#     283     # error: Argument 2 to "_bool_arith_check" has incompatible type
#     284     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
#     285     _bool_arith_check(op, left, right)  # type: ignore[arg-type]
#
# File ~\anaconda3\envs\Trabajos_Machine_2026\Lib\site-packages\pandas\core\arrays\numpy_.py:212, in NumpyExtensionArray.__array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#     205 def __array_ufunc__(self, ufunc: np.ufunc, method: str, *inputs, **kwargs):
#     206     # Lightly modified version of
#     207     # https://numpy.org/doc/stable/reference/generated/numpy.lib.mixins.NDArrayOperatorsMixin.html
#     208     # The primary modification is not boxing scalar return values
#     209     # in NumpyExtensionArray, since pandas' ExtensionArrays are 1-d.
#     210     out = kwargs.get("out", ())
# --> 212     result = arraylike.maybe_dispatch_ufunc_to_dunder_op(
#     213         self, ufunc, method, *inputs, **kwargs
#     214     )
#     215     if result is not NotImplemented:
#     216         return result
#
# File pandas/_libs/ops_dispatch.pyx:113, in pandas._libs.ops_dispatch.maybe_dispatch_ufunc_to_dunder_op()
# --> 113 'Could not get source, probably due dynamically evaluated source code.'
#
# File ~\anaconda3\envs\Trabajos_Machine_2026\Lib\site-packages\pandas\core\ops\common.py:85, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      82     other = sanitize_array(other, None)
#      83     other = ensure_wrapped_if_datetimelike(other)
# ---> 85 return method(self, other)
#
# File ~\anaconda3\envs\Trabajos_Machine_2026\Lib\site-packages\pandas\core\arraylike.py:202, in OpsMixin.__rsub__(self, other)
#     200 @unpack_zerodim_and_defer("__rsub__")
#     201 def __rsub__(self, other):
# --> 202     return self._arith_method(other, roperator.rsub)
#
# File ~\anaconda3\envs\Trabajos_Machine_2026\Lib\site-packages\pandas\core\arrays\string_.py:1218, in StringArray._cmp_method(self, other, op)
#    1216 result = np.empty_like(self._ndarray, dtype="object")
#    1217 result[mask] = self.dtype.na_value
# -> 1218 result[valid] = op(self._ndarray[valid], other)
#    1219 if isinstance(other, Path):
#    1220     # GH#61940
#    1221     return result
#
# File ~\anaconda3\envs\Trabajos_Machine_2026\Lib\site-packages\pandas\core\roperator.py:16, in rsub(left, right)
#      15 def rsub(left, right):
# ---> 16     return right - left
#
# TypeError: unsupported operand type(s) for -: 'int' and 'str'

# %% [markdown]
# Operaciones entre Series y DataFrames

# %%
rand_matrix = np.random.randint(10, size=(3, 4))
df = pd.DataFrame(rand_matrix , columns=list('ABCD'))
display(df)

display(df.iloc[0])
display(type(df.iloc[0]))
# uso común, averiguar la diferencia entre una fila y el resto
display(df - df.iloc[0])
display(df.sub(df.iloc[0], axis=1))
# Por columnas cómo se restaría
display(df.sub(df['A'], axis=0))
# Out:
#    A  B  C  D
# 0  4  4  6  9
# 1  0  0  4  2
# 2  8  0  1  0
# A    4
# B    4
# C    6
# D    9
# Name: 0, dtype: int32
# pandas.Series
#    A  B  C  D
# 0  0  0  0  0
# 1 -4 -4 -2 -7
# 2  4 -4 -5 -9
#    A  B  C  D
# 0  0  0  0  0
# 1 -4 -4 -2 -7
# 2  4 -4 -5 -9
#    A  B  C  D
# 0  0  0  2  5
# 1  0  0  4  2
# 2  0 -8 -7 -8

# %% [markdown]
# pandas se basa en NumPy, np operadores binarios y unarios son aceptables

# %% [markdown]
# | Tipo | Operación | Descripción |
# | :--- | :--- | :--- |
# | **Unario** | *abs* | Valor absoluto de cada elemento |
# | | *sqrt* | Raíz cuadrada de cada elemento |
# | | *exp* | e^x, siendo x cada elemento |
# | | *log, log10, log2* | Logaritmos en distintas bases de cada elemento |
# | | *sign* | Retorna el signo de cada elemento (-1 para negativo, 0 o 1 para positivo) |
# | | *ceil* | Redondea cada elemento por arriba |
# | | *floor* | Redondea cada elemento por abajo |
# | | *isnan* | Retorna si cada elemento es Nan |
# | | *cos, sin, tan* | Operaciones trigonométricas en cada elemento |
# | | *arccos, arcsin, arctan* | Inversas de operaciones trigonométricas en cada elemento |
# | **Binario** | *add* | Suma de dos arrays |
# | | *substruct* | Resta de dos arrays |
# | | *multiply* | Multiplicación de dos arrays |
# | | *divide* | División de dos arrays |
# | | *maximum, minimum* | Retorna el valor máximo/mínimo de cada pareja de elementos |
# | | *equal, not_equal* | Retorna la comparación (igual o no igual) de cada pareja de elementos |
# | | *greater, greater_equal, less, less_equal* | Retorna la comparación (>, >=, <, <= respectivamente) de cada pareja de elementos |

# %% [markdown]
# Aplicación de funciones a medida con lambda

# %%
rand_matrix = np.random.randint(10, size=(3, 4))
frame = pd.DataFrame(rand_matrix , columns=list('ABCD'))
display(frame)

print(frame.apply(lambda x : x.max() - x.min(), axis = 1)) # diferencia por columna
# Out:
#    A  B  C  D
# 0  5  5  5  2
# 1  7  0  6  7
# 2  5  7  8  6
# 0    3
# 1    7
# 2    3
# dtype: int32

# %%
def max_min(x):
    return x.max() - x.min()
    
print(frame.apply(max_min, axis = 0)) # diferencia por columna
# Out:
# A    2
# B    7
# C    3
# D    5
# dtype: int32

# %%
# diferencia entre min y max por fila (no columna)
rand_matrix = np.random.randint(10, size=(3, 4))
frame = pd.DataFrame(rand_matrix , columns=list('ABCD'))
display(frame)

print(frame.apply(lambda x : x.max() - x.min(), axis = 1)) # diferencia por fila
# Out:
#    A  B  C  D
# 0  5  6  0  6
# 1  6  0  1  4
# 2  9  2  5  2
# 0    6
# 1    6
# 2    7
# dtype: int32

# %% [markdown]
# ## 3 Estadística descriptiva
# * Análisis preliminar de los datos
# * Para Series y DataFrame

# %% [markdown]
# | Operación | Descripción |
# | :--- | :--- |
# | *count* | Número de valores no NaN |
# | *describe* | Conjunto de estadísticas sumarias |
# | *min, max* | Valores mínimo y máximo |
# | *argmin, argmax* | Índices posicionales del valor mínimo y máximo |
# | *idxmin, idxmax* | Índices semánticos del valor mínimo y máximo |
# | *sum* | Suma de los elementos |
# | *mean* | Media de los elementos |
# | *median* | Mediana de los elementos |
# | *mad* | Desviación absoluta media del valor medio |
# | *var* | Varianza de los elementos |
# | *std* | Desviación estándar de los elementos |
# | *cumsum* | Suma acumulada de los elementos |
# | *diff* | Diferencia aritmética de los elementos |

# %%
diccionario = { "nombre" : ["Marisa","Laura","Manuel", "Carlos"], "edad" : [34,34,11, 30],
                 "puntos" : [98,12,98,np.nan], "genero": ["F", "F", "M", "M"] }
frame = pd.DataFrame(diccionario)
display(frame)
display(frame.describe()) # datos generales de elementos
# Out:
#    nombre  edad  puntos genero
# 0  Marisa    34    98.0      F
# 1   Laura    34    12.0      F
# 2  Manuel    11    98.0      M
# 3  Carlos    30     NaN      M
#             edad     puntos
# count   4.000000   3.000000
# mean   27.250000  69.333333
# std    10.996211  49.652123
# min    11.000000  12.000000
# 25%    25.250000  55.000000
# 50%    32.000000  98.000000
# 75%    34.000000  98.000000
# max    34.000000  98.000000

# %%
# operadores básicos
print(frame.sum())

display(frame)
print(frame.sum(axis=1, numeric_only=True))
# Out:
# nombre    MarisaLauraManuelCarlos
# edad                          109
# puntos                      208.0
# genero                       FFMM
# dtype: object
#    nombre  edad  puntos genero
# 0  Marisa    34    98.0      F
# 1   Laura    34    12.0      F
# 2  Manuel    11    98.0      M
# 3  Carlos    30     NaN      M
# 0    132.0
# 1     46.0
# 2    109.0
# 3     30.0
# dtype: float64

# %%
frame.mean(numeric_only=True)
# Out:
# edad      27.250000
# puntos    69.333333
# dtype: float64

# %%
frame.cumsum()
# Out:
#                     nombre  edad  puntos genero
# 0                   Marisa    34    98.0      F
# 1              MarisaLaura    68   110.0     FF
# 2        MarisaLauraManuel    79   208.0    FFM
# 3  MarisaLauraManuelCarlos   109     NaN   FFMM

# %%
frame.count(axis=1)
# Out:
# 0    4
# 1    4
# 2    4
# 3    3
# dtype: int64

# %%
print(frame['edad'].std())
# Out:
# 10.996211468804457

# %%
frame['edad'].idxmax()
# Out:
# 0

# %%
frame['puntos'].idxmin()
# Out:
# 1

# %%
 # frame con las filas con los valores maximos de una columna
print(frame['puntos'].max())

display(frame[frame['puntos'] == frame['puntos'].max()])
# Out:
# 98.0
#    nombre  edad  puntos genero
# 0  Marisa    34    98.0      F
# 2  Manuel    11    98.0      M

# %%
frame["ranking"] = frame["puntos"].rank(method='max')

# %%
display(frame)
# Out:
#    nombre  edad  puntos genero  ranking
# 0  Marisa    34    98.0      F      3.0
# 1   Laura    34    12.0      F      1.0
# 2  Manuel    11    98.0      M      3.0
# 3  Carlos    30     NaN      M      NaN

# %% [markdown]
# ## 3.1 Agregaciones

# %%
display(frame)
df = frame.groupby('genero').count()
display(df)
# Out:
#    nombre  edad  puntos genero  ranking
# 0  Marisa    34    98.0      F      3.0
# 1   Laura    34    12.0      F      1.0
# 2  Manuel    11    98.0      M      3.0
# 3  Carlos    30     NaN      M      NaN
#         nombre  edad  puntos  ranking
# genero
# F            2     2       2        2
# M            2     2       1        1

# %%
# si es Nan descarta la fila
df = frame.groupby('puntos').count()
display(df)
# Out:
#         nombre  edad  genero  ranking
# puntos
# 12.0         1     1       1        1
# 98.0         2     2       2        2

# %%
display(frame.groupby('genero').mean(numeric_only=True))
# Out:
#         edad  puntos  ranking
# genero
# F       34.0    55.0      2.0
# M       20.5    98.0      3.0

# %%
display(frame.groupby('genero').max())
# Out:
#         nombre  edad  puntos  ranking
# genero
# F       Marisa    34    98.0      3.0
# M       Manuel    30    98.0      3.0

# %%
# funciones de agregación de varias columnas para obtener distintos estadísticos
display(frame.groupby('genero')[['edad', 'puntos']].aggregate(['min', 'mean', 'max']))
# Out:
#        edad           puntos
#         min  mean max    min  mean   max
# genero
# F        34  34.0  34   12.0  55.0  98.0
# M        11  20.5  30   98.0  98.0  98.0

# %%
# Filtrado de los datos en el que el conjunto no supera una media determinada
def media(x):
    return x["edad"].mean() > 30

display(frame)
frame.groupby('genero').filter(media)
# Out:
#    nombre  edad  puntos genero  ranking
# 0  Marisa    34    98.0      F      3.0
# 1   Laura    34    12.0      F      1.0
# 2  Manuel    11    98.0      M      3.0
# 3  Carlos    30     NaN      M      NaN
#    nombre  edad  puntos genero  ranking
# 0  Marisa    34    98.0      F      3.0
# 1   Laura    34    12.0      F      1.0

# %% [markdown]
# ## 3.2 Correlaciones
# pandas incluye métodos para analizar correlaciones - Relación matemática entre dos variables
# (-1 negativamente relacionadas, 1 positivamente relacionadas, 0 sin relación) - obj.corr(obj2) –
# > medida de correlación entre los datos de ambos objetos - https://blogs.oracle.com/ai-anddatascience/post/introduction-to-correlation

# %% [markdown]
# ## 3.2.1 Ejemplo Fuel efficiency
# * https://archive.ics.uci.edu/ml/datasets/Auto+MPG

# %%
import pandas as pd
path = 'http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data'

mpg_data = pd.read_csv(path, sep='\s+', header=None,
           names = ['mpg', 'cilindros', 'desplazamiento','potencia',
           'peso', 'aceleracion', 'año', 'origen', 'nombre'],
           na_values='?', engine='c')

# %%
display(mpg_data.sample(5))
# Out:
#       mpg  cilindros  desplazamiento  potencia    peso  aceleracion  año  \
# 65   14.0          8           351.0     153.0  4129.0         13.0   72
# 5    15.0          8           429.0     198.0  4341.0         10.0   70
# 200  18.0          6           250.0      78.0  3574.0         21.0   76
# 85   13.0          8           350.0     175.0  4100.0         13.0   73
# 130  26.0          4           122.0      80.0  2451.0         16.5   74
#
#      origen             nombre
# 65        1   ford galaxie 500
# 5         1   ford galaxie 500
# 200       1  ford granada ghia
# 85        1  buick century 350
# 130       1         ford pinto

# %%
display(mpg_data.describe(include='all'))
# Out:
#                mpg   cilindros  desplazamiento    potencia         peso  \
# count   398.000000  398.000000      398.000000  392.000000   398.000000
# unique         NaN         NaN             NaN         NaN          NaN
# top            NaN         NaN             NaN         NaN          NaN
# freq           NaN         NaN             NaN         NaN          NaN
# mean     23.514573    5.454774      193.425879  104.469388  2970.424623
# std       7.815984    1.701004      104.269838   38.491160   846.841774
# min       9.000000    3.000000       68.000000   46.000000  1613.000000
# 25%      17.500000    4.000000      104.250000   75.000000  2223.750000
# 50%      23.000000    4.000000      148.500000   93.500000  2803.500000
# 75%      29.000000    8.000000      262.000000  126.000000  3608.000000
# max      46.600000    8.000000      455.000000  230.000000  5140.000000
#
#         aceleracion         año      origen      nombre
# count    398.000000  398.000000  398.000000         398
# unique          NaN         NaN         NaN         305
# top             NaN         NaN         NaN  ford pinto
# freq            NaN         NaN         NaN           6
# mean      15.568090   76.010050    1.572864         NaN
# std        2.757689    3.697627    0.802055         NaN
# min        8.000000   70.000000    1.000000         NaN
# 25%       13.825000   73.000000    1.000000         NaN
# 50%       15.500000   76.000000    1.000000         NaN
# 75%       17.175000   79.000000    2.000000         NaN
# max       24.800000   82.000000    3.000000         NaN

# %%
mpg_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   mpg             398 non-null    float64
#  1   cilindros       398 non-null    int64
#  2   desplazamiento  398 non-null    float64
#  3   potencia        392 non-null    float64
#  4   peso            398 non-null    float64
#  5   aceleracion     398 non-null    float64
#  6   año             398 non-null    int64
#  7   origen          398 non-null    int64
#  8   nombre          398 non-null    str
# dtypes: float64(5), int64(3), str(1)
# memory usage: 28.1 KB

# %% [markdown]
# ## 3.2.2 Correlaciones entre valores

# %%
mpg_data['mpg'].corr(mpg_data['peso']) # + mpg = - peso
# Out:
# np.float64(-0.8317409332443354)

# %%
mpg_data['peso'].corr(mpg_data['aceleracion']) # + peso = - aceleracion
# Out:
# np.float64(-0.41745731994039337)

# %% [markdown]
# ## 3.2.3 Correlaciones entre todos los valores

# %%
mpg_data.corr(numeric_only=True)
# Out:
#                      mpg  cilindros  desplazamiento  potencia      peso  \
# mpg             1.000000  -0.775396       -0.804203 -0.778427 -0.831741
# cilindros      -0.775396   1.000000        0.950721  0.842983  0.896017
# desplazamiento -0.804203   0.950721        1.000000  0.897257  0.932824
# potencia       -0.778427   0.842983        0.897257  1.000000  0.864538
# peso           -0.831741   0.896017        0.932824  0.864538  1.000000
# aceleracion     0.420289  -0.505419       -0.543684 -0.689196 -0.417457
# año             0.579267  -0.348746       -0.370164 -0.416361 -0.306564
# origen          0.563450  -0.562543       -0.609409 -0.455171 -0.581024
#
#                 aceleracion       año    origen
# mpg                0.420289  0.579267  0.563450
# cilindros         -0.505419 -0.348746 -0.562543
# desplazamiento    -0.543684 -0.370164 -0.609409
# potencia          -0.689196 -0.416361 -0.455171
# peso              -0.417457 -0.306564 -0.581024
# aceleracion        1.000000  0.288137  0.205873
# año                0.288137  1.000000  0.180662
# origen             0.205873  0.180662  1.000000

# %%
#año y origen no parecen correlacionables
#eliminar columnas de la correlacion
corr_data = mpg_data.drop(['año','origen'],axis=1).corr(numeric_only=True)
display(corr_data)
# Out:
#                      mpg  cilindros  desplazamiento  potencia      peso  \
# mpg             1.000000  -0.775396       -0.804203 -0.778427 -0.831741
# cilindros      -0.775396   1.000000        0.950721  0.842983  0.896017
# desplazamiento -0.804203   0.950721        1.000000  0.897257  0.932824
# potencia       -0.778427   0.842983        0.897257  1.000000  0.864538
# peso           -0.831741   0.896017        0.932824  0.864538  1.000000
# aceleracion     0.420289  -0.505419       -0.543684 -0.689196 -0.417457
#
#                 aceleracion
# mpg                0.420289
# cilindros         -0.505419
# desplazamiento    -0.543684
# potencia          -0.689196
# peso              -0.417457
# aceleracion        1.000000

# %%
# representación gráfica matplotlib
import matplotlib.pyplot as plt

# %%
# representación gráfica
corr_data.style.background_gradient(cmap=plt.get_cmap('RdYlGn'), axis=1)
# Out:
# <style type="text/css">
# #T_012d6_row0_col0, #T_012d6_row1_col1, #T_012d6_row2_col2, #T_012d6_row3_col3, #T_012d6_row4_col4, #T_012d6_row5_col5 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_012d6_row0_col1, #T_012d6_row0_col3 {
#   background-color: #b30d26;
#   color: #f1f1f1;
# }
# #T_012d6_row0_col2 {
#   background-color: #ab0626;
#   color: #f1f1f1;
# }
# #T_012d6_row0_col4, #T_012d6_row1_col0, #T_012d6_row2_col0, #T_012d6_row3_col0, #T_012d6_row4_col0, #T_012d6_row5_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_012d6_row0_col5 {
#   background-color: #afdd70;
#   color: #000000;
# }
# #T_012d6_row1_col2 {
#   background-color: #07753e;
#   color: #f1f1f1;
# }
# #T_012d6_row1_col3, #T_012d6_row3_col1 {
#   background-color: #16914d;
#   color: #f1f1f1;
# }
# #T_012d6_row1_col4, #T_012d6_row2_col3, #T_012d6_row3_col2, #T_012d6_row4_col1 {
#   background-color: #0e8245;
#   color: #f1f1f1;
# }
# #T_012d6_row1_col5 {
#   background-color: #e54e35;
#   color: #f1f1f1;
# }
# #T_012d6_row2_col1 {
#   background-color: #06733d;
#   color: #f1f1f1;
# }
# #T_012d6_row2_col4, #T_012d6_row4_col2 {
#   background-color: #097940;
#   color: #f1f1f1;
# }
# #T_012d6_row2_col5 {
#   background-color: #e34933;
#   color: #f1f1f1;
# }
# #T_012d6_row3_col4 {
#   background-color: #138c4a;
#   color: #f1f1f1;
# }
# #T_012d6_row3_col5 {
#   background-color: #bd1726;
#   color: #f1f1f1;
# }
# #T_012d6_row4_col3 {
#   background-color: #128a49;
#   color: #f1f1f1;
# }
# #T_012d6_row4_col5 {
#   background-color: #f67c4a;
#   color: #f1f1f1;
# }
# #T_012d6_row5_col0 {
#   background-color: #bbe278;
#   color: #000000;
# }
# #T_012d6_row5_col1 {
#   background-color: #d93429;
#   color: #f1f1f1;
# }
# #T_012d6_row5_col2 {
#   background-color: #d02927;
#   color: #f1f1f1;
# }
# #T_012d6_row5_col4 {
#   background-color: #e95538;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_012d6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_012d6_level0_col0" class="col_heading level0 col0" >mpg</th>
#       <th id="T_012d6_level0_col1" class="col_heading level0 col1" >cilindros</th>
#       <th id="T_012d6_level0_col2" class="col_heading level0 col2" >desplazamiento</th>
#       <th id="T_012d6_level0_col3" class="col_heading level0 col3" >potencia</th>
#       <th id="T_012d6_level0_col4" class="col_heading level0 col4" >peso</th>
#       <th id="T_012d6_level0_col5" class="col_heading level0 col5" >aceleracion</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_012d6_level0_row0" class="row_heading level0 row0" >mpg</th>
#       <td id="T_012d6_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_012d6_row0_col1" class="data row0 col1" >-0.775396</td>
#       <td id="T_012d6_row0_col2" class="data row0 col2" >-0.804203</td>
#       <td id="T_012d6_row0_col3" class="data row0 col3" >-0.778427</td>
#       <td id="T_012d6_row0_col4" class="data row0 col4" >-0.831741</td>
#       <td id="T_012d6_row0_col5" class="data row0 col5" >0.420289</td>
#     </tr>
#     <tr>
#       <th id="T_012d6_level0_row1" class="row_heading level0 row1" >cilindros</th>
#       <td id="T_012d6_row1_col0" class="data row1 col0" >-0.775396</td>
#       <td id="T_012d6_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_012d6_row1_col2" class="data row1 col2" >0.950721</td>
#       <td id="T_012d6_row1_col3" class="data row1 col3" >0.842983</td>
#       <td id="T_012d6_row1_col4" class="data row1 col4" >0.896017</td>
#       <td id="T_012d6_row1_col5" class="data row1 col5" >-0.505419</td>
#     </tr>
#     <tr>
#       <th id="T_012d6_level0_row2" class="row_heading level0 row2" >desplazamiento</th>
#       <td id="T_012d6_row2_col0" class="data row2 col0" >-0.804203</td>
#       <td id="T_012d6_row2_col1" class="data row2 col1" >0.950721</td>
#       <td id="T_012d6_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_012d6_row2_col3" class="data row2 col3" >0.897257</td>
#       <td id="T_012d6_row2_col4" class="data row2 col4" >0.932824</td>
#       <td id="T_012d6_row2_col5" class="data row2 col5" >-0.543684</td>
#     </tr>
#     <tr>
#       <th id="T_012d6_level0_row3" class="row_heading level0 row3" >potencia</th>
#       <td id="T_012d6_row3_col0" class="data row3 col0" >-0.778427</td>
#       <td id="T_012d6_row3_col1" class="data row3 col1" >0.842983</td>
#       <td id="T_012d6_row3_col2" class="data row3 col2" >0.897257</td>
#       <td id="T_012d6_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_012d6_row3_col4" class="data row3 col4" >0.864538</td>
#       <td id="T_012d6_row3_col5" class="data row3 col5" >-0.689196</td>
#     </tr>
#     <tr>
#       <th id="T_012d6_level0_row4" class="row_heading level0 row4" >peso</th>
#       <td id="T_012d6_row4_col0" class="data row4 col0" >-0.831741</td>
#       <td id="T_012d6_row4_col1" class="data row4 col1" >0.896017</td>
#       <td id="T_012d6_row4_col2" class="data row4 col2" >0.932824</td>
#       <td id="T_012d6_row4_col3" class="data row4 col3" >0.864538</td>
#       <td id="T_012d6_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_012d6_row4_col5" class="data row4 col5" >-0.417457</td>
#     </tr>
#     <tr>
#       <th id="T_012d6_level0_row5" class="row_heading level0 row5" >aceleracion</th>
#       <td id="T_012d6_row5_col0" class="data row5 col0" >0.420289</td>
#       <td id="T_012d6_row5_col1" class="data row5 col1" >-0.505419</td>
#       <td id="T_012d6_row5_col2" class="data row5 col2" >-0.543684</td>
#       <td id="T_012d6_row5_col3" class="data row5 col3" >-0.689196</td>
#       <td id="T_012d6_row5_col4" class="data row5 col4" >-0.417457</td>
#       <td id="T_012d6_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# correlación más negativa
mpg_data.drop(['año','origen'],axis=1).corr(numeric_only=True).idxmin()
# Out:
# mpg                   peso
# cilindros              mpg
# desplazamiento         mpg
# potencia               mpg
# peso                   mpg
# aceleracion       potencia
# dtype: str

# %%
 # correlación más positiva
mpg_data.drop(['año','origen'],axis=1).corr(numeric_only=True).idxmax() #consigo misma...
# Out:
# mpg                          mpg
# cilindros              cilindros
# desplazamiento    desplazamiento
# potencia                potencia
# peso                        peso
# aceleracion          aceleracion
# dtype: str

# %%
positive_corr = mpg_data.drop(['año','origen'], axis=1).corr(numeric_only=True)

# Convertimos a un array de NumPy independiente y modificable
valores = positive_corr.to_numpy(copy=True)
np.fill_diagonal(valores, 0)

# Volvemos a meter los valores modificados dentro del DataFrame
positive_corr.iloc[:, :] = valores

display(positive_corr)
positive_corr.idxmax()
# Out:
#                      mpg  cilindros  desplazamiento  potencia      peso  \
# mpg             0.000000  -0.775396       -0.804203 -0.778427 -0.831741
# cilindros      -0.775396   0.000000        0.950721  0.842983  0.896017
# desplazamiento -0.804203   0.950721        0.000000  0.897257  0.932824
# potencia       -0.778427   0.842983        0.897257  0.000000  0.864538
# peso           -0.831741   0.896017        0.932824  0.864538  0.000000
# aceleracion     0.420289  -0.505419       -0.543684 -0.689196 -0.417457
#
#                 aceleracion
# mpg                0.420289
# cilindros         -0.505419
# desplazamiento    -0.543684
# potencia          -0.689196
# peso              -0.417457
# aceleracion        0.000000
# mpg                  aceleracion
# cilindros         desplazamiento
# desplazamiento         cilindros
# potencia          desplazamiento
# peso              desplazamiento
# aceleracion                  mpg
# dtype: str

# %%
positive_corr.style.background_gradient(cmap=plt.get_cmap('RdYlGn'), axis=1, vmin=-1.0, vmax=1.0)
# Out:
# <style type="text/css">
# #T_c0cb3_row0_col0, #T_c0cb3_row1_col1, #T_c0cb3_row2_col2, #T_c0cb3_row3_col3, #T_c0cb3_row4_col4, #T_c0cb3_row5_col5 {
#   background-color: #feffbe;
#   color: #000000;
# }
# #T_c0cb3_row0_col1, #T_c0cb3_row0_col3, #T_c0cb3_row1_col0, #T_c0cb3_row3_col0 {
#   background-color: #da362a;
#   color: #f1f1f1;
# }
# #T_c0cb3_row0_col2, #T_c0cb3_row2_col0 {
#   background-color: #d62f27;
#   color: #f1f1f1;
# }
# #T_c0cb3_row0_col4, #T_c0cb3_row4_col0 {
#   background-color: #ce2827;
#   color: #f1f1f1;
# }
# #T_c0cb3_row0_col5, #T_c0cb3_row5_col0 {
#   background-color: #a0d669;
#   color: #000000;
# }
# #T_c0cb3_row1_col2, #T_c0cb3_row2_col1 {
#   background-color: #06733d;
#   color: #f1f1f1;
# }
# #T_c0cb3_row1_col3, #T_c0cb3_row3_col1 {
#   background-color: #148e4b;
#   color: #f1f1f1;
# }
# #T_c0cb3_row1_col4, #T_c0cb3_row2_col3, #T_c0cb3_row3_col2, #T_c0cb3_row4_col1 {
#   background-color: #0d8044;
#   color: #f1f1f1;
# }
# #T_c0cb3_row1_col5, #T_c0cb3_row5_col1 {
#   background-color: #f88c51;
#   color: #f1f1f1;
# }
# #T_c0cb3_row2_col4, #T_c0cb3_row4_col2 {
#   background-color: #08773f;
#   color: #f1f1f1;
# }
# #T_c0cb3_row2_col5, #T_c0cb3_row5_col2 {
#   background-color: #f67f4b;
#   color: #f1f1f1;
# }
# #T_c0cb3_row3_col4, #T_c0cb3_row4_col3 {
#   background-color: #118848;
#   color: #f1f1f1;
# }
# #T_c0cb3_row3_col5, #T_c0cb3_row5_col3 {
#   background-color: #e65036;
#   color: #f1f1f1;
# }
# #T_c0cb3_row4_col5, #T_c0cb3_row5_col4 {
#   background-color: #fca85e;
#   color: #000000;
# }
# </style>
# <table id="T_c0cb3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c0cb3_level0_col0" class="col_heading level0 col0" >mpg</th>
#       <th id="T_c0cb3_level0_col1" class="col_heading level0 col1" >cilindros</th>
#       <th id="T_c0cb3_level0_col2" class="col_heading level0 col2" >desplazamiento</th>
#       <th id="T_c0cb3_level0_col3" class="col_heading level0 col3" >potencia</th>
#       <th id="T_c0cb3_level0_col4" class="col_heading level0 col4" >peso</th>
#       <th id="T_c0cb3_level0_col5" class="col_heading level0 col5" >aceleracion</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c0cb3_level0_row0" class="row_heading level0 row0" >mpg</th>
#       <td id="T_c0cb3_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_c0cb3_row0_col1" class="data row0 col1" >-0.775396</td>
#       <td id="T_c0cb3_row0_col2" class="data row0 col2" >-0.804203</td>
#       <td id="T_c0cb3_row0_col3" class="data row0 col3" >-0.778427</td>
#       <td id="T_c0cb3_row0_col4" class="data row0 col4" >-0.831741</td>
#       <td id="T_c0cb3_row0_col5" class="data row0 col5" >0.420289</td>
#     </tr>
#     <tr>
#       <th id="T_c0cb3_level0_row1" class="row_heading level0 row1" >cilindros</th>
#       <td id="T_c0cb3_row1_col0" class="data row1 col0" >-0.775396</td>
#       <td id="T_c0cb3_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_c0cb3_row1_col2" class="data row1 col2" >0.950721</td>
#       <td id="T_c0cb3_row1_col3" class="data row1 col3" >0.842983</td>
#       <td id="T_c0cb3_row1_col4" class="data row1 col4" >0.896017</td>
#       <td id="T_c0cb3_row1_col5" class="data row1 col5" >-0.505419</td>
#     </tr>
#     <tr>
#       <th id="T_c0cb3_level0_row2" class="row_heading level0 row2" >desplazamiento</th>
#       <td id="T_c0cb3_row2_col0" class="data row2 col0" >-0.804203</td>
#       <td id="T_c0cb3_row2_col1" class="data row2 col1" >0.950721</td>
#       <td id="T_c0cb3_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_c0cb3_row2_col3" class="data row2 col3" >0.897257</td>
#       <td id="T_c0cb3_row2_col4" class="data row2 col4" >0.932824</td>
#       <td id="T_c0cb3_row2_col5" class="data row2 col5" >-0.543684</td>
#     </tr>
#     <tr>
#       <th id="T_c0cb3_level0_row3" class="row_heading level0 row3" >potencia</th>
#       <td id="T_c0cb3_row3_col0" class="data row3 col0" >-0.778427</td>
#       <td id="T_c0cb3_row3_col1" class="data row3 col1" >0.842983</td>
#       <td id="T_c0cb3_row3_col2" class="data row3 col2" >0.897257</td>
#       <td id="T_c0cb3_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_c0cb3_row3_col4" class="data row3 col4" >0.864538</td>
#       <td id="T_c0cb3_row3_col5" class="data row3 col5" >-0.689196</td>
#     </tr>
#     <tr>
#       <th id="T_c0cb3_level0_row4" class="row_heading level0 row4" >peso</th>
#       <td id="T_c0cb3_row4_col0" class="data row4 col0" >-0.831741</td>
#       <td id="T_c0cb3_row4_col1" class="data row4 col1" >0.896017</td>
#       <td id="T_c0cb3_row4_col2" class="data row4 col2" >0.932824</td>
#       <td id="T_c0cb3_row4_col3" class="data row4 col3" >0.864538</td>
#       <td id="T_c0cb3_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_c0cb3_row4_col5" class="data row4 col5" >-0.417457</td>
#     </tr>
#     <tr>
#       <th id="T_c0cb3_level0_row5" class="row_heading level0 row5" >aceleracion</th>
#       <td id="T_c0cb3_row5_col0" class="data row5 col0" >0.420289</td>
#       <td id="T_c0cb3_row5_col1" class="data row5 col1" >-0.505419</td>
#       <td id="T_c0cb3_row5_col2" class="data row5 col2" >-0.543684</td>
#       <td id="T_c0cb3_row5_col3" class="data row5 col3" >-0.689196</td>
#       <td id="T_c0cb3_row5_col4" class="data row5 col4" >-0.417457</td>
#       <td id="T_c0cb3_row5_col5" class="data row5 col5" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 3.3 Ejercicios
# * Ejercicios para practicar Pandas: https://github.com/ajcr/100-pandaspuzzles/blob/master/100-pandas-puzzles.ipynb
